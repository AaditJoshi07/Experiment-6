# %% [markdown]
# Aadit Joshi
#
# 25070123173
#
# EXPERIMENT - 6
#
# Title- Study of conditional statements in Phyton

# %% [markdown]
# ### 1a. Check whether a number is positive or negative

# %%
num = int(input("Enter a number: "))

if num >= 0:
    print(f"{num} is a positive number.")
else:
    print(f"{num} is a negative number.")
# Out:
# Enter a number: -30
# -30 is a negative number.

# %% [markdown]
# ### 1b. Check whether a number is positive, negative, or zero

# %%
num = int(input("Enter a number: "))

if num > 0:
    print(f"{num} is a positive number.")
elif num < 0:
    print(f"{num} is a negative number.")
else:
    print("The number is zero.")
# Out:
# Enter a number: 0
# The number is zero.

# %%
#2. Check whether a number is even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")
# Out:
# Enter a number: 7
# 7 is an odd number.

# %%
#3.To find the largest number

a = int(input("Enter the first number (a): "))
b = int(input("Enter the second number (b): "))
c = int(input("Enter the third number (c): "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print(f"The largest number among {a}, {b}, and {c} is {largest}.")
# Out:
# Enter the first number (a): 5
# Enter the second number (b): 7
# Enter the third number (c): 9
# The largest number among 5, 7, and 9 is 9.

# %%
#4.Get input from user for a subject and find the grade

subject = input("Enter the subject name: ")
score = int(input(f"Enter the score for {subject}: "))

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"For {subject}, with a score of {score}, the grade is: {grade}")
# Out:
# Enter the subject name: maths
# Enter the score for maths: 70
# For maths, with a score of 70, the grade is: C

# %%
#5. Check whether a year is a leap year

year = int(input("Enter a year:"))
if (year % 400==0) or (year % 100!=0 and year % 4==0):
    print(f"{year} is a leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:2030
# Not a leap year

# %%
#6.Write a Program to increment any given date

date=input("Enter the date in format {dd/mm/yyyy}: ")
dd,mm,yy=date.split('/')
dd=int(dd)
mm=int(mm)
yy=int(yy)

if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
    max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
    max1=30
elif(yy%4==0 and yy%100!=0 or yy%400==0):
    max1=29
else:
    max1=28

if(mm<1 or mm>12):
    print("Date is invalid.")
elif(dd<1 or dd>max1):
    print("Date is invalid.")
elif(dd==max1 and mm!=12):
    dd=1
    mm=mm+1
    print("The incremented date is: ",dd,mm,yy)
elif(dd==31 and mm==12):
    dd=1
    mm=1
    yy=yy+1
    print("The incremented date is: ",dd,mm,yy)
else:
    dd=dd+1
    print("The incremented date is: ",dd,mm,yy)
# Out:
# Enter the date in format {dd/mm/yyyy}: 31/ 12/ 2026
# The incremented date is:  1 1 2027

# %%
#7.Check whether a character is vowel or consonant

char = input("Enter a character: ")

if char.upper() in 'aeiouAEIOU':
    print(f"{char} is a vowel.")
else:
   print(f"{char} is a consonant.")
# Out:
# Enter a character: A
# A is a vowel.

# %%
#8.WAP a program to calculate the gross salary of an employee

#if basic <=10000: HRA=20%, DA=80%
#if basic <=20000:HRA =30%, DA=95%
#otherwise: HRA = 30%, DA = 95%

basic = float(input("Enter basic salary: "))

if basic <=10000:
  hra = basic * 0.20
  da = basic *0.80

elif basic <=20000:
  hra = basic * 0.50
  da = basic * 0.90
else:
  hra = basic * 0.30
  da = basic *0.95

  gross = basic + hra + da
  print("Gross Salary:", gross)
# Out:
# Enter basic salary: 25000
# Gross Salary: 56250.0

# %%
''' 9.#WAP a program to calculate income tax based on annual income:
Upto $2,50,000: No tax
$2,50,001 - $5,00,000: 5%
$5,00,001 - $10,00,000: 20%
Above $10,00,000: 30%

income = float(input("Enter annual income:"))'''

income = float(input("Enter annual income:"))

if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = (income - 250000) * 0.05
elif income <= 1000000:
    tax = 12500 + (income - 500000) * 0.20
else:
    tax = 12500 + 100000 + (income - 1000000) * 0.30

print(f"The income tax is: ${tax:.2f}")
# Out:
# Enter annual income:600000
# The income tax is: $32500.00
